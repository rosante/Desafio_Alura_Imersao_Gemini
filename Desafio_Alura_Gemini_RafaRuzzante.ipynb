# %% [markdown]
# <a href="https://colab.research.google.com/github/rosante/Desafio_Alura_Imersao_Gemini/blob/master/Desafio_Alura_Gemini_RafaRuzzante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gerador de imagens 4k
# ![ImagemUltraRealista.jpg](data:image/jpeg;base64,...)
#
# # Instruções:
# Tente ser preciso na instrução, como por exemplo: um coelho

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai
from google.colab import userdata
my_api_key = userdata.get("my_api_key")
genai.configure(api_key=my_api_key)

# Set up the model
generation_config = {
  "temperature": 0.5,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

system_instruction = "Você é um artista"

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              system_instruction=system_instruction,
                              safety_settings=safety_settings)

chat = model.start_chat(history=[])

print("Digite SAIR para finalizar")

print("Esse chat apenas cria imagens super realistas, entao prepare a placa de vídeo...")

prompt = ""
while prompt != "SAIR":
	prompt = input("Pergunte ao Gemini: ")
	response = chat.send_message(f"Gere uma imagem ASCII sobre o seguinte texto: {prompt}")
	print(response.text)
# Out:
# Digite SAIR para finalizar
# Esse chat apenas cria imagens super realistas, entao prepare a placa de vídeo...
# Pergunte ao Gemini: um coelho
# ```
#    (\_/)
#   (='.'=)
#  (")_(")
# ```
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6bcfe7e55ea4> in <cell line: 53>()
#      52 prompt = ""
#      53 while prompt != "SAIR":
# ---> 54         prompt = input("Pergunte ao Gemini: ")
#      55         response = chat.send_message(f"Gere uma imagem ASCII sobre o seguinte texto: {prompt}")
#      56         print(response.text)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
# ...
